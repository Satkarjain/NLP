# %%
# %tensorflow_version 2.x
import tensorflow as tf
import collections
import math
import numpy as np
import os
import random
import bz2
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import nltk # standard preprocessing
import operator # sorting items in dictionary by value
#nltk.download() #tokenizers/punkt/PY3/english.pickle
from math import ceil
import csv

# %%
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    print('Downloading file...')
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

#filename = maybe_download('wikipedia2text-extracted.txt.bz2', 18377035)

# %%
url = 'http://mattmahoney.net/dc/'
filename = maybe_download('/content/drive/My Drive/text8.zip',  31344016)
# Out:
# Downloading file...
# Found and verified text8.zip

# %%
import zipfile

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
words = read_data("/content/drive/My Drive/text8.zip")
print('Data size %d' % len(words))
print('Example words (start): ',words[:10])
print('Example words (end): ',words[-10:])
# Out:
# Data size 17005207
# Example words (start):  ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# Example words (end):  ['in', 'one', 'nine', 'six', 'three', 'one', 'nine', 'six', 'five', 'b']

# %%
# we restrict our vocabulary size to 50000
vocabulary_size = 100000 

def build_dataset(words):
  count = [['UNK', -1]]
  # Gets only the vocabulary_size most common words as the vocabulary
  # All the other words will be replaced with UNK token
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()

  # Create an ID for each word by giving the current length of the dictionary
  # And adding that item to the dictionary
  for word, _ in count:
    dictionary[word] = len(dictionary)
    
  data = list()
  unk_count = 0
  # Traverse through all the text we have and produce a list
  # where each element corresponds to the ID of the word found at that index
  for word in words:
    # If word is in the dictionary use the word ID,
    # else use the ID of the special token "UNK"
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
    
  # update the count variable with the number of UNK occurences
  count[0][1] = unk_count
  
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  # Make sure the dictionary is of size of the vocabulary
  assert len(dictionary) == vocabulary_size
    
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 189230], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0
def generate_batch_skip_gram(batch_size, window_size):
  # data_index is updated by 1 everytime we read a data point
  global data_index 
    
  # two numpy arras to hold target words (batch)
  # and context words (labels)
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
  # span defines the total window size, where
  # data we consider at an instance looks as follows. 
  # [ skip_window target skip_window ]
  span = 2 * window_size + 1 
    
  # The buffer holds the data contained within the span
  buffer = collections.deque(maxlen=span)
  
  # Fill the buffer and update the data_index
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  # This is the number of context words we sample for a single target word
  num_samples = 2*window_size 

  # We break the batch reading into two for loops
  # The inner for loop fills in the batch and labels with 
  # num_samples data points using data contained withing the span
  # The outper for loop repeat this for batch_size//num_samples times
  # to produce a full batch
  for i in range(batch_size // num_samples):
    k=0
    # avoid the target word itself as a prediction
    # fill in batch and label numpy arrays
    for j in list(range(window_size))+list(range(window_size+1,2*window_size+1)):
      batch[i * num_samples + k] = buffer[window_size]
      labels[i * num_samples + k, 0] = buffer[j]
      k += 1 
    
    # Everytime we read num_samples data points,
    # we have created the maximum number of datapoints possible
    # withing a single span, so we need to move the span by 1
    # to create a fresh new span
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
batch_size = 128 # Data points in a single batch
embedding_size = 128 # Dimension of the embedding vector.
window_size = 4 # How many words to consider left and right.

# We pick a random validation set to sample nearest neighbors
valid_size = 16 # Random set of words to evaluate similarity on.
# We sample valid datapoints randomly from a large window without always being deterministic
valid_window = 50

# When selecting valid examples, we select some of the most frequent words as well as
# some moderately rare words as well
valid_examples = np.array(random.sample(range(valid_window), valid_size))
valid_examples = np.append(valid_examples,random.sample(range(1000, 1000+valid_window), valid_size),axis=0)

num_sampled = 32 # Number of negative examples to sample.

# %%
# !pip install tensorflow-gpu

# %%
print(tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
tf.reset_default_graph()

train_dataset = tf.placeholder(tf.int32 , shape = [batch_size])
train_labels = tf.placeholder(tf.int32,shape = [batch_size,1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %%
embeddings = tf.Variable(tf.random_uniform([vocabulary_size,embedding_size],-1,1))

softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size,embedding_size],stddev=0.5 / math.sqrt(embedding_size))
)

softmax_biases = tf.Variable(tf.random_uniform([vocabulary_size],0,0.01))

# %%
embed = tf.nn.embedding_lookup(embeddings,train_dataset)

loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights= softmax_weights,biases = softmax_biases,inputs = embed, labels = train_labels , num_sampled= num_sampled,num_classes=vocabulary_size))

# %%
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings),1,keepdims=True))
normalized_embeddings = embeddings / norm
vaild_embeddings  = tf.nn.embedding_lookup(normalized_embeddings,valid_dataset)
similarity = tf.matmul(vaild_embeddings,tf.transpose(normalized_embeddings))

# %%
optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/adagrad.py:77: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
num_steps = 100001
skip_losses = []

with tf.Session(config=tf.ConfigProto(allow_soft_placement=True)) as session:

  tf.global_variables_initializer().run()
  print("Variables initialised")

  average_loss = 0

  for step in range(num_steps):
    batch_data,batch_labels =  generate_batch_skip_gram(batch_size,window_size)
    feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
    _,l = session.run([optimizer,loss], feed_dict = feed_dict)
    average_loss+= l

    if (step+1) % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      
      skip_losses.append(average_loss)
     
      print('Average loss at step %d: %f' % (step+1, average_loss))
      average_loss = 0
    

    if (step+1) % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  skip_gram_final_embeddings = normalized_embeddings.eval()


np.save('skip_embeddings',skip_gram_final_embeddings)

with open('skip_losses.csv', 'wt') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(skip_losses)
# Out:
# Variables initialised
# Average loss at step 2000: 4.273452
# Average loss at step 4000: 3.761767
# Average loss at step 6000: 3.563912
# Average loss at step 8000: 3.509622
# Average loss at step 10000: 3.479837
# Nearest to have: has, satirizes, watts, liebermann, wetherell, values, saracen, harrovians,
# Nearest to he: s, that, his, be, motorsport, fitzmaurice, roddick, interfemoral,
# Nearest to four: five, zero, one, three, eight, two, nine, six,
# Nearest to by: and, in, baux, byng, that, destrier, magnoliopsida, gandamak,
# Nearest to some: esposito, hued, guppies, flemings, ttl, reymond, indecision, ahimsa,
# Nearest to this: worthiness, oquis, that, offensive, bronze, be, windhover, meeting,
# Nearest to that: or, for, he, and, this, on, it, solve,
# Nearest to UNK: three, and, four, invulnerable, krishnamurti, degenerated, succesor, pass,
# Nearest to on: with, s, and, oversimplification, principle, that, four, from,
# Nearest to the: a, s, of, in, one, and, cystitis, pointless,
# Nearest to were: aesthetics, entombed, pki, risd, trails, oblongata, forebear, native,
# Nearest to nine: eight, one, three, six, five, four, seven, two,
# Nearest to at: solely, s, freleng, ratna, bauhaus, climax, chanters, marshak,
# Nearest to s: bearden, the, on, and, he, three, in, his,
# Nearest to a: the, an, or, shortcuts, and, is, with, drood,
# Nearest to eight: nine, one, six, seven, three, five, four, two,
# Average loss at step 12000: 3.445315
# Average loss at step 14000: 3.489386
# Average loss at step 16000: 3.419984
# Average loss at step 18000: 3.373496
# Average loss at step 20000: 3.333167
# Nearest to have: has, be, alamannia, satirizes, had, basa, nutmeg, ethiopian,
# Nearest to he: was, his, it, as, that, signifiers, valderrama, firings,
# Nearest to four: two, five, six, one, three, eight, nine, zero,
# Nearest to by: was, with, micropolitan, s, tiques, pullout, attractant, from,
# Nearest to some: indecision, intoxicating, thummim, marceau, plonk, esposito, ahimsa, other,
# Nearest to this: an, tribal, its, sin, disapproving, briggs, bayqongyr, which,
# Nearest to that: which, greedy, but, he, when, unleavened, arguer, dravidian,
# Nearest to UNK: and, six, valentina, transamerica, at, deception, d, five,
# Nearest to on: in, pair, powering, trigraph, wetzler, swings, larpa, intelligible,
# Nearest to the: of, in, a, an, from, thrill, s, hireling,
# Nearest to were: are, was, curiosities, had, circumcisions, misdemeanour, adjani, maintenon,
# Nearest to nine: one, eight, three, five, two, zero, six, seven,
# Nearest to at: UNK, in, s, document, ahvaz, suburban, avalanches, superfluid,
# Nearest to s: a, his, by, in, was, an, four, at,
# Nearest to a: an, s, the, his, as, conium, triangle, mimicking,
# Nearest to eight: seven, one, nine, six, five, three, four, zero,
# Average loss at step 22000: 3.366951
# Average loss at step 24000: 3.345124
# Average loss at step 26000: 3.416066
# Average loss at step 28000: 3.316832
# Average loss at step 30000: 3.305679
# Nearest to have: are, be, has, had, nutmeg, satirizes, beholder, as,
# Nearest to he: that, it, him, his, had, when, who, mous,
# Nearest to four: zero, six, one, nine, two, five, three, seven,
# Nearest to by: and, in, with, of, replacing, thesis, captivated, or,
# Nearest to some: marceau, as, other, they, these, indecision, hued, most,
# Nearest to this: it, that, which, an, a, the, also, whether,
# Nearest to that: it, this, which, he, to, be, not, roscommon,
# Nearest to UNK: s, doves, is, from, excision, orally, sina, temenos,
# Nearest to on: at, to, with, from, wingspan, and, megastructures, guayaquil,
# Nearest to the: a, and, of, an, or, in, with, is,
# Nearest to were: are, was, had, wield, their, surveyor, precipice, aesthetics,
# Nearest to nine: seven, four, six, five, eight, one, zero, three,
# Nearest to at: on, south, missives, of, druze, terrorizes, perctarit, ei,
# Nearest to s: UNK, his, ductility, and, by, canto, in, ammonium,
# Nearest to a: the, and, an, of, is, n, creaky, or,
# Nearest to eight: seven, nine, one, six, five, four, two, zero,
# Average loss at step 32000: 3.330882
# Average loss at step 34000: 3.298664
# Average loss at step 36000: 3.146231
# Average loss at step 38000: 3.293844
# Average loss at step 40000: 3.154946
# Nearest to have: has, had, be, risa, thorvaldsen, it, laurel, herod,
# Nearest to he: it, but, they, higginson, mous, fairview, until, him,
# Nearest to four: one, seven, eight, three, six, five, nine, two,
# Nearest to by: with, ecb, and, as, which, heligoland, from, octave,
# Nearest to some: many, these, most, protozoa, prooem, been, tishbite, roundness,
# Nearest to this: nahal, changeable, templeton, friulian, ikiru, railroad, philippics, that,
# Nearest to that: be, which, they, not, no, timoshenko, it, shay,
# Nearest to UNK: van, encephalomyelitis, princess, sadomasochistic, pub, greek, homoeroticism, paraphrased,
# Nearest to on: from, after, into, with, intelligible, stereoisomers, genetical, attractant,
# Nearest to the: a, fishman, crustacean, and, archimandrite, distrust, till, arnstadt,
# Nearest to were: are, had, many, their, they, was, patriated, uninteresting,
# Nearest to nine: one, eight, seven, six, four, five, two, three,
# Nearest to at: into, oskar, presburger, smirnoff, pycnometer, accuser, pervert, aen,
# Nearest to s: a, myasthenia, as, tats, and, links, opera, by,
# Nearest to a: the, an, s, tetroxide, and, kodeksi, showcase, antipodes,
# Nearest to eight: seven, six, one, nine, five, four, three, two,
# Average loss at step 42000: 3.190253
# Average loss at step 44000: 3.211892
# Average loss at step 46000: 3.261648
# Average loss at step 48000: 3.318964
# Average loss at step 50000: 3.218066
# Nearest to have: has, had, be, some, many, uktv, often, also,
# Nearest to he: it, but, who, not, when, him, she, made,
# Nearest to four: three, zero, five, two, eight, six, one, seven,
# Nearest to by: for, a, on, lorina, blob, that, which, who,
# Nearest to some: many, most, fluttering, dingo, are, these, have, all,
# Nearest to this: it, but, that, not, also, almsgiving, aj, courts,
# Nearest to that: when, which, it, this, annihilate, incorrigible, by, said,
# Nearest to UNK: assassinates, e, dam, loader, monophthongs, bohdan, and, pub,
# Nearest to on: in, by, stereoisomers, of, into, and, to, s,
# Nearest to the: a, and, s, to, their, in, his, of,
# Nearest to were: are, was, had, dixie, they, their, zhongguancun, slaves,
# Nearest to nine: eight, six, five, one, two, seven, four, three,
# Nearest to at: about, on, senatus, oskar, malinois, presburger, accuser, volgograd,
# Nearest to s: the, and, in, first, invariably, on, withdrew, a,
# Nearest to a: the, an, it, by, prohibited, and, for, stapledon,
# Nearest to eight: nine, six, five, one, four, seven, three, two,
# Average loss at step 52000: 3.264766
# Average loss at step 54000: 3.234221
# Average loss at step 56000: 3.233013
# Average loss at step 58000: 3.228847
# Average loss at step 60000: 3.251550
# Nearest to have: has, had, gravina, cnd, be, glasser, stabilise, are,
# Nearest to he: it, him, his, she, when, after, god, alicia,
# Nearest to four: five, six, three, eight, two, seven, one, zero,
# Nearest to by: with, an, into, trustees, and, petitioners, obesity, docetism,
# Nearest to some: many, most, these, several, been, ghosted, paramilitary, laos,
# Nearest to this: its, gereformeerde, the, it, which, sequencer, only, disqualify,
# Nearest to that: which, also, it, not, outlays, when, might, who,
# Nearest to UNK: such, priss, kanyakumari, karun, a, reactos, unn, kion,
# Nearest to on: in, stereoisomers, through, into, of, sobieski, claudio, at,
# Nearest to the: and, a, in, an, s, of, this, which,
# Nearest to were: was, are, had, being, tiberius, requiem, dispossession, most,
# Nearest to nine: seven, eight, one, five, six, zero, four, three,
# Nearest to at: rampant, crm, pycnometer, aleksei, accuser, creations, halakist, concavity,
# Nearest to s: the, three, champs, szdsz, uncopyrightable, two, annexed, one,
# Nearest to a: the, an, and, with, prandtl, UNK, stirrup, its,
# Nearest to eight: seven, nine, five, four, three, one, six, two,
# Average loss at step 62000: 3.267303
# Average loss at step 64000: 3.225386
# Average loss at step 66000: 3.251995
# Average loss at step 68000: 3.268250
# Average loss at step 70000: 3.292118
# Nearest to have: has, had, be, possesion, many, are, several, albeit,
# Nearest to he: she, his, him, who, when, it, that, later,
# Nearest to four: five, six, seven, two, eight, three, nine, one,
# Nearest to by: when, and, yak, which, with, the, of, under,
# Nearest to some: many, these, several, other, different, been, however, recent,
# Nearest to this: that, it, trebouxiophyceae, a, vidhan, but, the, when,
# Nearest to that: this, however, when, also, to, it, which, who,
# Nearest to UNK: de, openssh, m, firestone, g, belgian, n, e,
# Nearest to on: stereoisomers, at, in, with, baillaud, micha, deprecation, protocol,
# Nearest to the: a, and, an, by, his, s, any, for,
# Nearest to were: are, was, had, deployable, some, have, escap, being,
# Nearest to nine: eight, seven, one, six, four, zero, two, three,
# Nearest to at: lin, on, after, where, ratite, nab, off, creations,
# Nearest to s: the, mcdonald, links, executive, oxbridge, external, quakerism, assets,
# Nearest to a: the, an, any, this, if, by, no, and,
# Nearest to eight: nine, seven, six, one, four, five, three, zero,
# Average loss at step 72000: 3.178051
# Average loss at step 74000: 3.223999
# Average loss at step 76000: 3.262095
# Average loss at step 78000: 3.286192
# Average loss at step 80000: 3.239264
# Nearest to have: has, had, be, many, infringed, who, schoolly, were,
# Nearest to he: she, him, his, later, it, father, what, baptism,
# Nearest to four: three, five, seven, six, eight, two, one, nine,
# Nearest to by: and, was, in, contemplativa, s, called, which, biologist,
# Nearest to some: many, all, these, even, marceau, several, other, who,
# Nearest to this: it, a, what, that, an, the, battlements, jenson,
# Nearest to that: this, although, which, since, it, there, where, miaphysite,
# Nearest to UNK: de, i, et, references, irrepressible, or, mitzvah, uttar,
# Nearest to on: in, stereoisomers, burali, until, jermaine, fault, surreal, sisak,
# Nearest to the: a, and, its, in, of, to, this, laois,
# Nearest to were: are, was, saimei, had, predella, they, vcr, have,
# Nearest to nine: eight, seven, six, five, one, four, zero, three,
# Nearest to at: larpa, school, submarineby, noms, where, university, accuser, in,
# Nearest to s: vitas, comorbid, in, by, links, ultrasparc, dredd, turishcheva,
# Nearest to a: the, an, this, another, it, walford, because, and,
# Nearest to eight: six, nine, seven, four, one, five, three, two,
# Average loss at step 82000: 3.298102
# Average loss at step 84000: 3.171130
# Average loss at step 86000: 3.267820
# Average loss at step 88000: 3.278889
# Average loss at step 90000: 3.229375
# Nearest to have: has, had, be, schoolly, zodiacal, some, poststructuralism, basslines,
# Nearest to he: she, him, it, was, his, later, when, that,
# Nearest to four: five, seven, eight, six, three, two, one, zero,
# Nearest to by: into, baghd, lachey, heligoland, who, kofi, however, parvati,
# Nearest to some: many, these, several, other, all, they, even, most,
# Nearest to this: it, a, not, that, because, what, when, he,
# Nearest to that: but, when, if, to, because, this, it, he,
# Nearest to UNK: or, delimiting, de, called, la, g, singles, family,
# Nearest to on: and, in, with, of, while, at, before, when,
# Nearest to the: a, and, an, i, in, her, s, his,
# Nearest to were: was, are, had, became, many, hamdan, them, could,
# Nearest to nine: eight, six, seven, one, zero, three, five, four,
# Nearest to at: when, while, before, on, where, dsc, time, assisi,
# Nearest to s: the, and, in, his, was, then, gravitating, he,
# Nearest to a: the, it, an, this, her, and, kadena, he,
# Nearest to eight: six, four, seven, five, nine, one, three, zero,
# Average loss at step 92000: 3.257507
# Average loss at step 94000: 3.212468
# Average loss at step 96000: 3.032119
# Average loss at step 98000: 3.019470
# Average loss at step 100000: 3.266491
# Nearest to have: has, had, are, be, were, some, zodiacal, many,
# Nearest to he: she, his, him, it, himself, had, said, who,
# Nearest to four: seven, six, three, eight, five, two, zero, one,
# Nearest to by: and, with, which, trentham, wildcats, s, however, hussey,
# Nearest to some: many, other, these, even, several, all, such, their,
# Nearest to this: it, a, its, that, an, another, what, but,
# Nearest to that: but, to, if, although, before, this, however, also,
# Nearest to UNK: e, b, and, or, drilling, group, et, de,
# Nearest to on: two, released, for, leveque, but, freese, three, taqiyya,
# Nearest to the: a, their, s, and, any, its, it, instrumentalyst,
# Nearest to were: are, was, many, permeating, had, have, mccay, idir,
# Nearest to nine: eight, one, two, three, six, seven, four, zero,
# Nearest to at: while, when, chattanooga, metamorphoses, pictograms, time, scherbius, where,
# Nearest to s: the, and, his, from, three, procellariiformes, by, in,
# Nearest to a: an, the, another, this, every, each, its, any,
# Nearest to eight: three, seven, nine, four, one, two, five, six,

# %%
def find_clustered_embeddings(embeddings,distance_threshold,sample_threshold):
    ''' 
    Find only the closely clustered embeddings. 
    This gets rid of more sparsly distributed word embeddings and make the visualization clearer
    This is useful for t-SNE visualization
    
    distance_threshold: maximum distance between two points to qualify as neighbors
    sample_threshold: number of neighbors required to be considered a cluster
    '''
    
    # calculate cosine similarity
    cosine_sim = np.dot(embeddings,np.transpose(embeddings))
    norm = np.dot(np.sum(embeddings**2,axis=1).reshape(-1,1),np.sum(np.transpose(embeddings)**2,axis=0).reshape(1,-1))
    assert cosine_sim.shape == norm.shape
    cosine_sim /= norm
    
    # make all the diagonal entries zero otherwise this will be picked as highest
    np.fill_diagonal(cosine_sim, -1.0)
    
    argmax_cos_sim = np.argmax(cosine_sim, axis=1)
    mod_cos_sim = cosine_sim
    # find the maximums in a loop to count if there are more than n items above threshold
    for _ in range(sample_threshold-1):
        argmax_cos_sim = np.argmax(cosine_sim, axis=1)
        mod_cos_sim[np.arange(mod_cos_sim.shape[0]),argmax_cos_sim] = -1
    
    max_cosine_sim = np.max(mod_cos_sim,axis=1)

    return np.where(max_cosine_sim>distance_threshold)[0]

# %%
num_points = 1000 # we will use a large sample space to build the T-SNE manifold and then prune it using cosine similarity

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)

print('Fitting embeddings to T-SNE. This can take some time ...')
# get the T-SNE manifold
selected_embeddings = cbow_final_embeddings[:num_points, :]
two_d_embeddings = tsne.fit_transform(selected_embeddings)

print('Pruning the T-SNE embeddings')
# prune the embeddings by getting ones only more than n-many sample above the similarity threshold
# this unclutters the visualization
selected_ids = find_clustered_embeddings(selected_embeddings,.25,10)
two_d_embeddings = two_d_embeddings[selected_ids,:]

print('Out of ',num_points,' samples, ', selected_ids.shape[0],' samples were selected by pruning')
# Out:
# Fitting embeddings to T-SNE. This can take some time ...
# Pruning the T-SNE embeddings
# Out of  1000  samples,  650  samples were selected by pruning

# %%
def plot(embeddings, labels):
  
  n_clusters = 20 # number of clusters
  # automatically build a discrete set of colors, each for cluster
  #label_colors = [pylab.cm.get_cmap(float(i) /n_clusters) for i in range(n_clusters)]
  
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  
  # Define K-Means
  kmeans = KMeans(n_clusters=n_clusters, init='k-means++', random_state=0).fit(embeddings)
  kmeans_labels = kmeans.labels_
  
  pylab.figure(figsize=(15,15))  # in inches
    
  # plot all the embeddings and their corresponding words
  for i, (label,klabel) in enumerate(zip(labels,kmeans_labels)):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)    
        
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom',fontsize=10)

  # use for saving the figure if needed
  #pylab.savefig('word_embeddings.png')
  pylab.show()

words = [reverse_dictionary[i] for i in selected_ids]
plot(two_d_embeddings, words)

# %%
data_index = 0
def generate_batch_cbow(batch_size, window_size):
  global data_index

  span = 2*window_size +1
  batch = np.ndarray(shape = (batch_size,span-1),dtype = np.int32)
  labels = np.ndarray(shape = (batch_size,1), dtype = np.int32)

  buffer = collections.deque(maxlen = span)

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index+1)% len(data)

  for i in range(batch_size):

        target = window_size  # target label at the center of the buffer
        target_to_avoid = [ window_size ] # we only need to know the words around a given word, not the word itself

        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            # ignore the target word when creating the batch
            if j==span//2:
                continue
            batch[i,col_idx] = buffer[j] 
            col_idx += 1
        labels[i, 0] = buffer[target]

        # Everytime we read a data point,
        # we need to move the span by 1
        # to create a fresh new span
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

  return batch, labels

# %%
  batch, labels = generate_batch_cbow(8,2)

# %%
print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
# Out:
#     batch: [['radicals', 'including', 'diggers', 'of'], ['including', 'the', 'of', 'the'], ['the', 'diggers', 'the', 'english'], ['diggers', 'of', 'english', 'revolution'], ['of', 'the', 'revolution', 'and'], ['the', 'english', 'and', 'the'], ['english', 'revolution', 'the', 'sans'], ['revolution', 'and', 'sans', 'culottes']]

# %%
batch_size = 128 # Data points in a single batch
embedding_size = 128 # Dimension of the embedding vector.
# How many words to consider left and right.
# Skip gram by design does not require to have all the context words in a given step
# However, for CBOW that's a requirement, so we limit the window size
window_size = 2 

# We pick a random validation set to sample nearest neighbors
valid_size = 16 # Random set of words to evaluate similarity on.
# We sample valid datapoints randomly from a large window without always being deterministic
valid_window = 50

# When selecting valid examples, we select some of the most frequent words as well as
# some moderately rare words as well
valid_examples = np.array(random.sample(range(valid_window), valid_size))
valid_examples = np.append(valid_examples,random.sample(range(1000, 1000+valid_window), valid_size),axis=0)

num_sampled = 32 # Number of negative examples to sample.

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
tf.reset_default_graph()

# Training input data (target word IDs). Note that it has 2*window_size columns
train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*window_size])
# Training input label data (context word IDs)
train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
# Validation input data, we don't need a placeholder
# as we have already defined the IDs of the words selected
# as validation data
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %%
embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0,dtype=tf.float32))

# Softmax Weights and Biases
softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                 stddev=0.5 / math.sqrt(embedding_size),dtype=tf.float32))
softmax_biases = tf.Variable(tf.random_uniform([vocabulary_size],0.0,0.01))

# %%
stacked_embedings = None
print('Defining %d embedding lookups representing each word in the context'%(2*window_size))
for i in range(2*window_size):
    embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])        
    x_size,y_size = embedding_i.get_shape().as_list()
    if stacked_embedings is None:
        stacked_embedings = tf.reshape(embedding_i,[x_size,y_size,1])
    else:
        stacked_embedings = tf.concat(axis=2,values=[stacked_embedings,tf.reshape(embedding_i,[x_size,y_size,1])])

assert stacked_embedings.get_shape().as_list()[2]==2*window_size
print("Stacked embedding size: %s"%stacked_embedings.get_shape().as_list())
mean_embeddings =  tf.reduce_mean(stacked_embedings,2,keepdims=False)
print("Reduced mean embedding size: %s"%mean_embeddings.get_shape().as_list())
# Out:
# Defining 4 embedding lookups representing each word in the context
# Stacked embedding size: [128, 128, 4]
# Reduced mean embedding size: [128, 128]

# %%
loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=mean_embeddings,
                           labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

# %%
optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

# %%
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 500001
cbow_losses = []

# ConfigProto is a way of providing various configuration settings 
# required to execute the graph
with tf.Session(config=tf.ConfigProto(allow_soft_placement=True)) as session:
    
    # Initialize the variables in the graph
    tf.global_variables_initializer().run()
    print('Initialized')
    
    average_loss = 0
    
    # Train the Word2vec model for num_step iterations
    for step in range(num_steps):
        
        # Generate a single batch of data
        batch_data, batch_labels = generate_batch_cbow(batch_size, window_size)
        
        # Populate the feed_dict and run the optimizer (minimize loss)
        # and compute the loss
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        
        # Update the average loss variable
        average_loss += l
        
        if (step+1) % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            cbow_losses.append(average_loss)
            print('Average loss at step %d: %f' % (step+1, average_loss))
            average_loss = 0
            
        # Evaluating validation set word similarities
        if (step+1) % 10000 == 0:
            sim = similarity.eval()
            # Here we compute the top_k closest words for a given validation word
            # in terms of the cosine distance
            # We do this for all the words in the validation set
            # Note: This is an expensive step
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    cbow_final_embeddings = normalized_embeddings.eval()
    

np.save('cbow_embeddings',cbow_final_embeddings)

with open('cbow_losses.csv', 'wt') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(cbow_losses)
# Out:
# Initialized
# Average loss at step 2000: 3.696585
# Average loss at step 4000: 3.134075
# Average loss at step 6000: 3.007796
# Average loss at step 8000: 2.886862
# Average loss at step 10000: 2.831536
# Nearest to had: has, have, hipster, was, greenway, satires, yawning, croesus,
# Nearest to which: that, rongelap, this, ubisoft, galtieri, yeomans, visionaries, astor,
# Nearest to they: we, jevons, these, atolls, ambre, mineraloids, barrier, fox,
# Nearest to with: speicherstadt, parallels, describing, maps, accents, lumbar, spivey, boudinot,
# Nearest to the: its, mes, this, pluralized, an, zenga, cateau, vox,
# Nearest to but: while, exhibitionism, then, although, modernist, wies, revolutionists, fruit,
# Nearest to some: musket, many, pub, wainwright, hungary, illes, most, puente,
# Nearest to three: six, zero, seven, two, five, hardie, nevsky, eight,
# Nearest to eight: nine, seven, zero, six, four, five, three, vitriolic,
# Nearest to an: rito, assayed, the, calvinism, collectivists, boron, gnutella, ku,
# Nearest to s: his, assayas, kth, definable, dube, hove, bilinear, interruption,
# Nearest to at: household, marillion, labienus, declining, groceries, backstory, akc, backlit,
# Nearest to other: professionals, averell, grundprobleme, ytmnd, some, cities, efik, tcl,
# Nearest to also: cyrene, often, spingarn, cupbearer, tashiro, sidekick, wu, americanized,
# Nearest to its: their, the, his, her, legato, eremetic, whose, wolpert,
# Nearest to are: were, is, carry, metaphorically, testifies, rds, germaniae, tutankhamun,
# Average loss at step 12000: 2.810579
# Average loss at step 14000: 2.801174
# Average loss at step 16000: 2.694228
# Average loss at step 18000: 2.544596
# Average loss at step 20000: 2.571670
# Nearest to had: has, have, was, hipster, greenway, yawning, kariba, viagra,
# Nearest to which: that, this, rongelap, yeomans, ubisoft, iniquities, scanned, mexican,
# Nearest to they: we, you, there, these, ambre, mineraloids, atolls, jevons,
# Nearest to with: bore, maps, dysphoria, vei, parallels, accents, greystone, soldier,
# Nearest to the: its, this, mes, their, a, another, cateau, pluralized,
# Nearest to but: although, revolutionists, while, however, exhibitionism, fruit, established, kenney,
# Nearest to some: many, musket, most, wainwright, several, all, tufnel, pub,
# Nearest to three: six, four, five, seven, two, eight, zero, hardie,
# Nearest to eight: seven, nine, six, five, four, zero, three, vitriolic,
# Nearest to an: rito, collectivists, assayed, walsingham, pseudopods, another, deter, reginae,
# Nearest to s: his, kth, dube, bilinear, her, lindow, hove, citrix,
# Nearest to at: household, marillion, akc, webtv, desylva, declining, backstory, heuristic,
# Nearest to other: professionals, these, blonde, accumulated, some, many, ideological, cities,
# Nearest to also: cyrene, cupbearer, tashiro, americanized, townshend, generally, abrasives, often,
# Nearest to its: their, the, his, her, whose, regno, halachic, wolpert,
# Nearest to are: were, is, have, beag, testifies, metaphorically, stibnite, tutankhamun,
# Average loss at step 22000: 2.680812
# Average loss at step 24000: 2.578377
# Average loss at step 26000: 2.598862
# Average loss at step 28000: 2.650187
# Average loss at step 30000: 2.567263
# Nearest to had: has, have, was, greenway, hipster, having, became, viagra,
# Nearest to which: that, this, rongelap, iniquities, yeomans, glassware, ubisoft, transliterated,
# Nearest to they: we, you, ambre, belies, there, mineraloids, variables, gonadal,
# Nearest to with: bore, xiith, kippur, accents, parallels, vei, soldier, villon,
# Nearest to the: its, zenga, mes, their, pluralized, cateau, heretical, another,
# Nearest to but: although, however, exhibitionism, concilia, revolutionists, synder, fruit, trap,
# Nearest to some: many, several, most, various, musket, all, alarmist, wainwright,
# Nearest to three: four, five, seven, eight, six, two, zero, nevsky,
# Nearest to eight: seven, six, nine, four, five, three, zero, two,
# Nearest to an: rito, collectivists, assayed, another, pseudopods, spiner, reginae, readmission,
# Nearest to s: his, kth, her, dube, bilinear, hove, citrix, lindow,
# Nearest to at: marillion, household, webtv, backstory, desylva, akc, enlightenment, resolution,
# Nearest to other: professionals, various, these, some, mastery, yorktown, blonde, several,
# Nearest to also: cupbearer, generally, cyrene, townshend, clarisworks, poppy, irishman, now,
# Nearest to its: their, his, the, her, regno, exhaust, whose, halachic,
# Nearest to are: were, is, have, beag, testifies, stibnite, carry, fato,
# Average loss at step 32000: 2.540389
# Average loss at step 34000: 2.533098
# Average loss at step 36000: 2.462013
# Average loss at step 38000: 2.486314
# Average loss at step 40000: 2.504567
# Nearest to had: has, have, having, was, greenway, paralysed, viagra, handfuls,
# Nearest to which: that, this, iniquities, rongelap, these, unconstrained, yeomans, where,
# Nearest to they: we, you, he, gonadal, there, belies, ambre, these,
# Nearest to with: bore, xiith, describing, soldier, parallels, accents, vei, kippur,
# Nearest to the: its, their, our, another, macedonia, mes, a, whose,
# Nearest to but: however, although, and, trap, while, synder, ottewell, revolutionists,
# Nearest to some: many, several, various, most, musket, all, alarmist, other,
# Nearest to three: four, five, seven, six, two, eight, zero, nine,
# Nearest to eight: seven, six, nine, four, five, zero, three, obnoxious,
# Nearest to an: rito, another, collectivists, assayed, pseudopods, reginae, spiner, provenance,
# Nearest to s: kth, his, her, hove, dube, helmuth, citrix, bilinear,
# Nearest to at: marillion, household, webtv, enlightenment, desylva, backlit, heuristic, exodus,
# Nearest to other: professionals, various, these, some, mastery, several, speckled, inflectional,
# Nearest to also: cupbearer, townshend, now, generally, below, often, cyrene, tashiro,
# Nearest to its: their, the, his, whose, our, regno, exhaust, wolpert,
# Nearest to are: were, is, have, beag, include, stibnite, metaphorically, microscopist,
# Average loss at step 42000: 2.506747
# Average loss at step 44000: 2.533242
# Average loss at step 46000: 2.494617
# Average loss at step 48000: 2.403451
# Average loss at step 50000: 2.494400
# Nearest to had: has, have, having, was, paralysed, greenway, were, priestley,
# Nearest to which: that, this, where, yeomans, reticulata, transliterated, iniquities, maples,
# Nearest to they: we, you, he, there, gonadal, dinh, ambre, belies,
# Nearest to with: xiith, bore, vei, between, kippur, experienced, accents, megaptera,
# Nearest to the: your, its, our, swindle, a, their, mes, cantor,
# Nearest to but: however, although, and, trap, though, while, ottewell, macivory,
# Nearest to some: many, various, several, most, musket, alarmist, these, all,
# Nearest to three: four, five, seven, two, six, eight, zero, sars,
# Nearest to eight: nine, six, seven, four, five, zero, three, vitriolic,
# Nearest to an: another, rito, collectivists, assayed, deter, pseudopods, reginae, spiner,
# Nearest to s: his, her, kth, citrix, dube, helmuth, hove, rbb,
# Nearest to at: marillion, household, enlightenment, backlit, webtv, desylva, agape, exodus,
# Nearest to other: various, professionals, these, speckled, mastery, different, some, moirae,
# Nearest to also: below, generally, cupbearer, townshend, now, often, poppy, tashiro,
# Nearest to its: their, his, our, regno, whose, the, her, nft,
# Nearest to are: were, is, beag, be, have, metaphorically, stibnite, include,
# Average loss at step 52000: 2.469567
# Average loss at step 54000: 2.473132
# Average loss at step 56000: 2.479941
# Average loss at step 58000: 2.414258
# Average loss at step 60000: 2.300869
# Nearest to had: has, have, having, was, greenway, paralysed, priestley, midwestern,
# Nearest to which: that, this, what, where, yeomans, disconnection, unconstrained, iniquities,
# Nearest to they: we, you, he, there, gonadal, dinh, ambre, these,
# Nearest to with: xiith, bore, between, vei, megaptera, experienced, accents, soldier,
# Nearest to the: our, cateau, mes, pluralized, your, its, gissing, attempting,
# Nearest to but: although, however, though, while, ottewell, and, trap, undeciphered,
# Nearest to some: many, several, various, most, all, musket, these, other,
# Nearest to three: four, five, six, seven, eight, two, zero, palio,
# Nearest to eight: seven, six, nine, five, four, zero, three, optic,
# Nearest to an: another, rito, assayed, collectivists, spiner, reginae, pseudopods, walsingham,
# Nearest to s: his, dube, kth, hove, citrix, gilbreth, signification, bilinear,
# Nearest to at: marillion, household, backlit, webtv, enlightenment, misdiagnosed, unassisted, agape,
# Nearest to other: various, professionals, these, speckled, different, some, accumulated, mastery,
# Nearest to also: below, now, generally, cupbearer, often, still, townshend, tashiro,
# Nearest to its: their, his, our, regno, ieng, whose, nft, the,
# Nearest to are: were, is, have, beag, metaphorically, include, radiolarians, testifies,
# Average loss at step 62000: 2.432411
# Average loss at step 64000: 2.417190
# Average loss at step 66000: 2.409932
# Average loss at step 68000: 2.422402
# Average loss at step 70000: 2.451264
# Nearest to had: has, have, having, was, paralysed, priestley, greenway, were,
# Nearest to which: that, this, where, these, disconnection, reticulata, iniquities, what,
# Nearest to they: we, you, he, gonadal, there, dinh, belies, she,
# Nearest to with: xiith, bore, vei, between, megaptera, describing, kippur, experienced,
# Nearest to the: a, its, your, attempting, mes, their, our, this,
# Nearest to but: although, however, while, though, and, cielo, trap, ottewell,
# Nearest to some: many, several, various, most, wainwright, all, certain, intoxicated,
# Nearest to three: four, five, six, two, seven, eight, zero, mulliken,
# Nearest to eight: seven, six, nine, five, four, zero, three, two,
# Nearest to an: another, rito, collectivists, assayed, walsingham, pseudopods, reginae, deter,
# Nearest to s: his, kth, dube, lindow, hove, my, her, jolie,
# Nearest to at: webtv, enlightenment, marillion, household, ransome, unassisted, backlit, wisc,
# Nearest to other: various, professionals, these, speckled, different, mastery, moirae, accumulated,
# Nearest to also: below, now, cupbearer, still, generally, often, poppy, peloponessus,
# Nearest to its: their, his, our, regno, the, whose, ieng, nft,
# Nearest to are: were, is, beag, have, stibnite, was, include, metaphorically,
# Average loss at step 72000: 2.409767
# Average loss at step 74000: 2.437156
# Average loss at step 76000: 2.350043
# Average loss at step 78000: 2.347985
# Average loss at step 80000: 2.391300
# Nearest to had: has, have, having, was, were, greenway, paralysed, priestley,
# Nearest to which: that, this, where, these, what, disconnection, iniquities, unconstrained,
# Nearest to they: we, you, he, there, gonadal, she, belies, atolls,
# Nearest to with: bore, xiith, vei, describing, experienced, megaptera, soldier, between,
# Nearest to the: our, your, its, mes, their, a, bumping, attempting,
# Nearest to but: although, however, though, while, and, tribhuvan, oyly, trap,
# Nearest to some: many, several, various, most, certain, intoxicated, wainwright, all,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to eight: seven, six, nine, five, four, three, zero, sloman,
# Nearest to an: another, rito, collectivists, deter, assayed, pseudopods, spiner, provenance,
# Nearest to s: his, kth, dube, her, murray, isbn, my, rbb,
# Nearest to at: webtv, unassisted, during, household, marillion, enlightenment, near, misdiagnosed,
# Nearest to other: various, professionals, speckled, these, accumulated, different, moirae, yorktown,
# Nearest to also: below, now, cupbearer, often, still, peloponessus, generally, disambiguation,
# Nearest to its: their, his, our, regno, the, nft, ieng, whose,
# Nearest to are: were, is, beag, have, remain, include, stibnite, be,
# Average loss at step 82000: 2.388824
# Average loss at step 84000: 2.268012
# Average loss at step 86000: 2.349678
# Average loss at step 88000: 2.368454
# Average loss at step 90000: 2.359014
# Nearest to had: has, have, having, was, were, priestley, paralysed, greenway,
# Nearest to which: that, this, what, where, these, pomegranate, unconstrained, iniquities,
# Nearest to they: we, you, he, gonadal, there, she, belies, dinh,
# Nearest to with: xiith, vei, bore, megaptera, experienced, between, villon, lyotropic,
# Nearest to the: its, your, a, our, mes, their, attempting, xnor,
# Nearest to but: although, however, though, while, and, ottewell, fooling, cielo,
# Nearest to some: many, several, various, most, certain, all, wainwright, intoxicated,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to eight: seven, six, nine, five, four, three, zero, definitives,
# Nearest to an: another, rito, collectivists, assayed, spiner, fumarate, provenance, pseudopods,
# Nearest to s: his, her, kth, dube, helmuth, citrix, lindow, gilbreth,
# Nearest to at: near, during, webtv, enlightenment, marillion, unassisted, dismas, household,
# Nearest to other: various, professionals, speckled, these, accumulated, different, individual, moirae,
# Nearest to also: below, now, often, cupbearer, still, peloponessus, disambiguation, sanger,
# Nearest to its: their, his, our, regno, the, her, whose, ieng,
# Nearest to are: were, is, have, remain, beag, ccny, stibnite, include,
# Average loss at step 92000: 2.281182
# Average loss at step 94000: 2.271729
# Average loss at step 96000: 2.293501
# Average loss at step 98000: 2.343499
# Average loss at step 100000: 2.271997
# Nearest to had: has, have, having, was, were, priestley, greenway, paralysed,
# Nearest to which: that, this, these, where, what, disconnection, dago, iniquities,
# Nearest to they: we, you, he, gonadal, dinh, there, she, cays,
# Nearest to with: vei, bore, megaptera, between, xiith, experienced, villon, describing,
# Nearest to the: its, attempting, mes, a, cateau, capable, zenga, their,
# Nearest to but: however, although, though, while, and, see, chihiro, idiosyncrasy,
# Nearest to some: many, several, various, most, certain, all, wainwright, both,
# Nearest to three: five, four, six, seven, eight, two, zero, rence,
# Nearest to eight: seven, six, five, nine, four, three, zero, two,
# Nearest to an: another, rito, assayed, collectivists, reginae, enthusiasts, deter, bouillon,
# Nearest to s: his, kth, lope, rbb, dube, whose, freescale, lindow,
# Nearest to at: during, near, webtv, unassisted, enlightenment, desylva, marillion, dismas,
# Nearest to other: various, professionals, speckled, these, individual, accumulated, moirae, different,
# Nearest to also: below, now, often, cupbearer, still, disambiguation, generally, peloponessus,
# Nearest to its: their, his, our, the, regno, ieng, nft, whose,
# Nearest to are: were, is, have, include, beag, remain, stibnite, ccny,
# Average loss at step 102000: 2.257009
# Average loss at step 104000: 2.349170
# Average loss at step 106000: 2.342790
# Average loss at step 108000: 2.235598
# Average loss at step 110000: 2.314733
# Nearest to had: has, have, having, paralysed, priestley, was, were, greenway,
# Nearest to which: that, this, where, what, these, disconnection, unconstrained, vestige,
# Nearest to they: we, you, he, there, gonadal, tenured, cays, she,
# Nearest to with: between, vei, bore, megaptera, xiith, experienced, intendant, speicherstadt,
# Nearest to the: our, its, mes, their, your, eurasianet, macedonia, a,
# Nearest to but: however, although, though, see, while, and, trap, chihiro,
# Nearest to some: many, several, various, most, certain, all, numerous, both,
# Nearest to three: five, four, six, seven, eight, two, zero, several,
# Nearest to eight: seven, six, nine, four, five, three, zero, chapter,
# Nearest to an: another, rito, assayed, collectivists, parapsychologists, spiner, stelios, walsingham,
# Nearest to s: his, whose, kth, her, dube, my, rbb, isbn,
# Nearest to at: near, during, unassisted, webtv, marillion, desylva, dismas, stallings,
# Nearest to other: various, professionals, these, speckled, accumulated, different, individual, fewer,
# Nearest to also: below, now, cupbearer, often, disambiguation, still, generally, peloponessus,
# Nearest to its: their, his, our, regno, the, ieng, nft, her,
# Nearest to are: were, is, have, include, remain, beag, ccny, stibnite,
# Average loss at step 112000: 2.268069
# Average loss at step 114000: 2.289086
# Average loss at step 116000: 2.313598
# Average loss at step 118000: 2.226395
# Average loss at step 120000: 2.274057
# Nearest to had: has, have, having, priestley, was, paralysed, were, greenway,
# Nearest to which: that, this, where, what, disconnection, these, also, unconstrained,
# Nearest to they: we, you, he, gonadal, there, she, belies, corticospinal,
# Nearest to with: between, bore, vei, megaptera, describing, experienced, xiith, lyotropic,
# Nearest to the: its, their, our, mes, capable, macedonia, zenga, bumping,
# Nearest to but: however, although, though, see, and, trap, while, tribhuvan,
# Nearest to some: many, several, various, most, all, certain, numerous, both,
# Nearest to three: four, six, five, seven, eight, two, zero, expensively,
# Nearest to eight: six, seven, zero, nine, four, five, three, bit,
# Nearest to an: another, rito, collectivists, assayed, spiner, deter, pseudopods, fumarate,
# Nearest to s: kth, rbb, his, dube, carat, delamielleure, whose, lope,
# Nearest to at: near, dismas, during, around, webtv, marillion, unassisted, enlightenment,
# Nearest to other: professionals, various, speckled, accumulated, these, different, individual, fewer,
# Nearest to also: below, now, still, cupbearer, often, generally, disambiguation, peloponessus,
# Nearest to its: their, his, our, the, regno, ieng, whose, her,
# Nearest to are: were, is, have, remain, include, beag, was, stibnite,
# Average loss at step 122000: 2.274599
# Average loss at step 124000: 2.066695
# Average loss at step 126000: 1.940861
# Average loss at step 128000: 2.162135
# Average loss at step 130000: 2.189854
# Nearest to had: has, have, having, was, priestley, showed, paralysed, greenway,
# Nearest to which: that, this, what, where, unconstrained, disconnection, these, also,
# Nearest to they: we, you, he, she, gonadal, there, belies, cays,
# Nearest to with: between, xiith, vei, bore, megaptera, experienced, describing, wikitravel,
# Nearest to the: macedonia, mes, cateau, its, attempting, our, zenga, bumping,
# Nearest to but: however, although, though, trap, see, and, while, tribhuvan,
# Nearest to some: many, several, various, most, certain, all, numerous, both,
# Nearest to three: four, five, six, seven, two, eight, zero, nine,
# Nearest to eight: seven, six, four, five, nine, zero, three, mercier,
# Nearest to an: another, rito, collectivists, assayed, spiner, deter, considerable, fumarate,
# Nearest to s: his, my, her, kth, rbb, whose, citrix, lope,
# Nearest to at: near, during, unassisted, stallings, webtv, desylva, dismas, around,
# Nearest to other: various, professionals, speckled, these, accumulated, different, individual, including,
# Nearest to also: below, now, often, peloponessus, still, cupbearer, disambiguation, sanger,
# Nearest to its: their, his, our, her, regno, ieng, whose, the,
# Nearest to are: were, is, remain, include, have, beag, ccny, testifies,
# Average loss at step 132000: 2.171794
# Average loss at step 134000: 2.236199
# Average loss at step 136000: 2.092406
# Average loss at step 138000: 2.183125
# Average loss at step 140000: 2.194105
# Nearest to had: has, have, having, priestley, was, paralysed, mieczys, showed,
# Nearest to which: that, this, what, where, disconnection, unconstrained, these, sutlej,
# Nearest to they: we, you, he, there, she, gonadal, corticospinal, tenured,
# Nearest to with: bore, xiith, vei, between, megaptera, describing, lyotropic, poissy,
# Nearest to the: mes, attempting, swindle, zenga, its, our, iuma, umb,
# Nearest to but: however, although, though, trap, macivory, oxycodone, tribhuvan, while,
# Nearest to some: many, several, various, most, certain, all, numerous, both,
# Nearest to three: four, six, five, seven, two, eight, zero, paullinus,
# Nearest to eight: six, seven, nine, four, five, zero, three, baskets,
# Nearest to an: another, rito, assayed, collectivists, deter, spiner, stelios, fumarate,
# Nearest to s: rbb, kth, my, his, dube, freescale, carat, isbn,
# Nearest to at: near, during, webtv, marillion, unassisted, stallings, kei, around,
# Nearest to other: various, professionals, speckled, accumulated, these, fewer, different, individual,
# Nearest to also: below, now, often, cupbearer, still, disambiguation, peloponessus, generally,
# Nearest to its: their, his, our, regno, ieng, whose, her, the,
# Nearest to are: were, is, remain, beag, include, have, ccny, exist,
# Average loss at step 142000: 2.236614
# Average loss at step 144000: 2.099438
# Average loss at step 146000: 2.011491
# Average loss at step 148000: 2.067150
# Average loss at step 150000: 2.199487
# Nearest to had: has, have, having, was, priestley, mieczys, showed, paralysed,
# Nearest to which: that, this, what, where, unconstrained, these, disconnection, vestige,
# Nearest to they: we, you, he, there, she, gonadal, belies, corticospinal,
# Nearest to with: bore, xiith, between, megaptera, vei, describing, plus, psychohistory,
# Nearest to the: mes, attempting, its, swindle, bumping, our, capable, xnor,
# Nearest to but: however, although, though, trap, digested, macivory, see, because,
# Nearest to some: many, several, various, most, certain, numerous, both, wainwright,
# Nearest to three: four, six, five, seven, two, eight, zero, paullinus,
# Nearest to eight: seven, six, four, nine, five, zero, three, hashed,
# Nearest to an: another, rito, collectivists, assayed, spiner, deter, stelios, fumarate,
# Nearest to s: rbb, kth, his, isbn, carat, her, dube, my,
# Nearest to at: near, during, webtv, unassisted, marillion, around, stallings, enlightenment,
# Nearest to other: various, professionals, speckled, these, individual, fewer, accumulated, different,
# Nearest to also: below, now, still, disambiguation, cupbearer, often, peloponessus, wasteful,
# Nearest to its: their, his, our, her, whose, ieng, regno, the,
# Nearest to are: were, is, remain, beag, include, have, ccny, various,
# Average loss at step 152000: 2.111512
# Average loss at step 154000: 2.182247
# Average loss at step 156000: 2.203271
# Average loss at step 158000: 2.133744
# Average loss at step 160000: 2.132494
# Nearest to had: has, have, having, priestley, knew, was, showed, saw,
# Nearest to which: that, where, this, what, disconnection, unconstrained, these, iniquities,
# Nearest to they: we, you, he, there, she, gonadal, belies, tenured,
# Nearest to with: bore, xiith, between, megaptera, vei, describing, accolades, lyotropic,
# Nearest to the: mes, attempting, its, our, zenga, cateau, novellae, gissing,
# Nearest to but: however, although, though, trap, see, oxycodone, digested, and,
# Nearest to some: many, several, various, most, numerous, certain, alarmist, all,
# Nearest to three: four, five, seven, six, two, eight, zero, gullah,
# Nearest to eight: seven, six, five, nine, four, three, zero, two,
# Nearest to an: another, rito, collectivists, assayed, spiner, stelios, bouillon, huppert,
# Nearest to s: his, freescale, kth, my, whose, her, dube, rbb,
# Nearest to at: near, during, unassisted, marillion, webtv, stallings, bibles, dismas,
# Nearest to other: various, professionals, speckled, these, individual, fewer, accumulated, different,
# Nearest to also: below, now, disambiguation, still, cupbearer, often, peloponessus, sanger,
# Nearest to its: their, his, our, her, ieng, regno, whose, your,
# Nearest to are: were, is, remain, include, beag, ccny, exist, have,
# Average loss at step 162000: 2.148292
# Average loss at step 164000: 2.084671
# Average loss at step 166000: 2.128891
# Average loss at step 168000: 2.136639
# Average loss at step 170000: 2.162009
# Nearest to had: has, have, having, priestley, was, paralysed, were, knew,
# Nearest to which: that, this, what, where, iniquities, unconstrained, these, disconnection,
# Nearest to they: we, you, he, she, there, tenured, gonadal, onna,
# Nearest to with: bore, xiith, megaptera, vei, between, nanotechnologies, regulatory, describing,
# Nearest to the: its, attempting, a, mes, their, bumping, peoplehood, our,
# Nearest to but: however, although, though, and, trap, see, idiosyncrasy, because,
# Nearest to some: many, several, various, most, certain, numerous, alarmist, both,
# Nearest to three: four, seven, six, two, five, eight, zero, mb,
# Nearest to eight: six, seven, four, five, nine, three, zero, two,
# Nearest to an: another, rito, collectivists, assayed, parapsychologists, spiner, stelios, considerable,
# Nearest to s: whose, kth, dube, isbn, rbb, his, freescale, lope,
# Nearest to at: near, during, unassisted, webtv, stallings, marillion, enlightenment, bibles,
# Nearest to other: various, speckled, professionals, these, accumulated, individual, fewer, different,
# Nearest to also: now, below, still, disambiguation, cupbearer, often, peloponessus, clarisworks,
# Nearest to its: their, his, our, ieng, her, whose, the, regno,
# Nearest to are: were, is, remain, include, have, beag, ccny, exist,
# Average loss at step 172000: 2.171727
# Average loss at step 174000: 2.113577
# Average loss at step 176000: 2.086151
# Average loss at step 178000: 2.162721
# Average loss at step 180000: 2.168320
# Nearest to had: has, have, having, was, were, priestley, paralysed, showed,
# Nearest to which: that, this, what, where, vestige, unconstrained, these, pomegranate,
# Nearest to they: we, you, he, she, there, gonadal, honed, belies,
# Nearest to with: bore, xiith, megaptera, vei, between, poissy, experienced, doctype,
# Nearest to the: our, a, their, kebabs, concilium, mes, bumping, your,
# Nearest to but: however, although, though, and, trap, macivory, see, while,
# Nearest to some: many, several, various, numerous, certain, most, alarmist, all,
# Nearest to three: four, seven, six, five, two, eight, zero, ten,
# Nearest to eight: six, seven, five, nine, four, zero, three, tobal,
# Nearest to an: another, rito, collectivists, assayed, spiner, parapsychologists, considerable, stelios,
# Nearest to s: his, whose, kth, dube, my, hove, her, mechatronics,
# Nearest to at: near, during, unassisted, stallings, webtv, wisc, bibles, backlit,
# Nearest to other: various, speckled, professionals, these, individual, accumulated, fewer, dad,
# Nearest to also: below, now, still, disambiguation, often, cupbearer, clarisworks, peloponessus,
# Nearest to its: their, his, our, her, whose, ieng, regno, your,
# Nearest to are: were, is, remain, ccny, include, have, radiolarians, exist,
# Average loss at step 182000: 2.173677
# Average loss at step 184000: 2.165547
# Average loss at step 186000: 2.092863
# Average loss at step 188000: 1.997026
# Average loss at step 190000: 2.128113
# Nearest to had: has, have, having, priestley, was, showed, knew, paralysed,
# Nearest to which: that, what, this, where, unconstrained, these, iniquities, disconnection,
# Nearest to they: we, you, he, there, she, gonadal, tenured, honed,
# Nearest to with: bore, between, xiith, vei, megaptera, psychohistory, nanotechnologies, inquisitional,
# Nearest to the: mes, zenga, its, cateau, bumping, attempting, our, swindle,
# Nearest to but: however, although, though, see, macivory, trap, compaor, mitsumi,
# Nearest to some: many, several, various, numerous, certain, most, all, wainwright,
# Nearest to three: four, five, six, two, seven, eight, zero, ten,
# Nearest to eight: six, seven, five, nine, four, zero, three, two,
# Nearest to an: another, collectivists, rito, assayed, stelios, spiner, fumarate, deter,
# Nearest to s: kth, dube, rbb, kobold, whose, mechatronics, isbn, his,
# Nearest to at: near, during, unassisted, webtv, marillion, enlightenment, kei, stallings,
# Nearest to other: various, speckled, professionals, individual, these, fewer, accumulated, fiefdoms,
# Nearest to also: below, still, now, disambiguation, cupbearer, clarisworks, often, fulmar,
# Nearest to its: their, his, our, ieng, her, whose, regno, your,
# Nearest to are: were, is, remain, contain, have, include, beag, ccny,
# Average loss at step 192000: 2.118029
# Average loss at step 194000: 2.102572
# Average loss at step 196000: 2.140216
# Average loss at step 198000: 2.172783
# Average loss at step 200000: 2.143984
# Nearest to had: has, have, having, priestley, was, were, paralysed, knew,
# Nearest to which: that, this, what, where, unconstrained, these, disconnection, vestige,
# Nearest to they: we, you, he, there, she, tenured, gonadal, inclined,
# Nearest to with: bore, xiith, vei, megaptera, between, describing, nanotechnologies, psychohistory,
# Nearest to the: attempting, its, their, our, mes, a, cateau, novellae,
# Nearest to but: however, although, though, see, and, while, macivory, trap,
# Nearest to some: many, several, various, numerous, certain, most, wainwright, all,
# Nearest to three: four, five, two, six, seven, eight, mb, zero,
# Nearest to eight: six, seven, nine, five, four, zero, three, bureaucrash,
# Nearest to an: another, rito, collectivists, assayed, deter, parapsychologists, stelios, spiner,
# Nearest to s: kth, whose, delamielleure, rbb, dube, his, bolshoi, mechatronics,
# Nearest to at: near, unassisted, during, webtv, stallings, marillion, ransome, viking,
# Nearest to other: various, professionals, individual, speckled, these, fewer, accumulated, different,
# Nearest to also: below, disambiguation, still, now, cupbearer, peloponessus, actually, often,
# Nearest to its: their, his, our, her, ieng, whose, the, regno,
# Nearest to are: were, is, remain, exist, contain, have, represent, include,
# Average loss at step 202000: 2.162032
# Average loss at step 204000: 2.091565
# Average loss at step 206000: 2.093724
# Average loss at step 208000: 2.148634
# Average loss at step 210000: 2.129556
# Nearest to had: has, have, having, was, priestley, showed, were, knew,
# Nearest to which: that, this, what, where, unconstrained, these, vestige, disconnection,
# Nearest to they: we, you, he, there, gonadal, she, honed, tenured,
# Nearest to with: bore, xiith, vei, megaptera, between, describing, plus, lyotropic,
# Nearest to the: mes, zenga, our, attempting, its, concilium, bumping, a,
# Nearest to but: however, although, though, see, trap, while, and, idiosyncrasy,
# Nearest to some: many, several, various, numerous, certain, most, wainwright, all,
# Nearest to three: four, five, six, seven, two, eight, zero, mb,
# Nearest to eight: six, seven, nine, five, four, three, zero, bureaucrash,
# Nearest to an: another, collectivists, rito, spiner, assayed, stelios, parapsychologists, deter,
# Nearest to s: kth, whose, his, rbb, dube, delamielleure, isbn, mechatronics,
# Nearest to at: near, during, unassisted, webtv, ransome, dismas, around, stallings,
# Nearest to other: various, individual, professionals, speckled, these, fewer, accumulated, axial,
# Nearest to also: below, disambiguation, now, still, cupbearer, actually, often, which,
# Nearest to its: their, his, our, her, ieng, whose, regno, your,
# Nearest to are: were, remain, is, exist, have, contain, beag, include,
# Average loss at step 212000: 2.025849
# Average loss at step 214000: 2.104088
# Average loss at step 216000: 2.118526
# Average loss at step 218000: 2.120648
# Average loss at step 220000: 2.045817
# Nearest to had: has, have, having, showed, were, was, priestley, paralysed,
# Nearest to which: that, this, where, what, unconstrained, disconnection, these, pomegranate,
# Nearest to they: we, you, he, there, gonadal, tenured, she, honed,
# Nearest to with: bore, xiith, vei, megaptera, regulatory, clipper, between, villon,
# Nearest to the: a, mes, attempting, their, its, our, cateau, bumping,
# Nearest to but: however, although, though, see, because, while, and, idiosyncrasy,
# Nearest to some: many, several, numerous, various, certain, most, wainwright, hundreds,
# Nearest to three: four, five, six, seven, two, eight, zero, ten,
# Nearest to eight: seven, six, nine, four, five, three, zero, ufc,
# Nearest to an: another, rito, collectivists, assayed, spiner, fumarate, parapsychologists, stelios,
# Nearest to s: kth, whose, dube, lope, his, rbb, freescale, helmuth,
# Nearest to at: near, during, webtv, unassisted, marillion, dismas, around, stallings,
# Nearest to other: various, speckled, professionals, individual, these, fewer, accumulated, csm,
# Nearest to also: below, disambiguation, now, still, cupbearer, often, actually, nevertheless,
# Nearest to its: their, his, our, her, ieng, whose, regno, your,
# Nearest to are: were, is, remain, exist, beag, have, include, contain,
# Average loss at step 222000: 2.041863
# Average loss at step 224000: 2.090661
# Average loss at step 226000: 2.120467
# Average loss at step 228000: 2.041131
# Average loss at step 230000: 2.053209
# Nearest to had: has, have, having, were, priestley, showed, was, paralysed,
# Nearest to which: that, this, where, what, unconstrained, disconnection, but, pomegranate,
# Nearest to they: we, you, he, gonadal, there, tenured, she, honed,
# Nearest to with: bore, vei, xiith, megaptera, between, describing, celeron, johansen,
# Nearest to the: mes, attempting, its, our, gissing, zenga, a, concilium,
# Nearest to but: however, although, though, see, while, fooling, tribhuvan, trap,
# Nearest to some: many, several, various, certain, numerous, most, all, wainwright,
# Nearest to three: four, five, six, seven, two, eight, zero, generalises,
# Nearest to eight: six, seven, nine, five, four, zero, three, bit,
# Nearest to an: another, rito, collectivists, assayed, stelios, hives, parapsychologists, fumarate,
# Nearest to s: kth, rbb, dube, his, whose, freescale, yasukuni, lope,
# Nearest to at: near, during, stallings, unassisted, webtv, dismas, marillion, ransome,
# Nearest to other: professionals, various, speckled, individual, fewer, these, csm, accumulated,
# Nearest to also: below, disambiguation, now, still, cupbearer, actually, peloponessus, often,
# Nearest to its: their, his, our, ieng, her, the, regno, whose,
# Nearest to are: were, is, remain, include, contain, exist, beag, have,
# Average loss at step 232000: 2.126927
# Average loss at step 234000: 2.140151
# Average loss at step 236000: 2.004655
# Average loss at step 238000: 2.119503
# Average loss at step 240000: 2.072256
# Nearest to had: has, have, having, priestley, ve, paralysed, showed, was,
# Nearest to which: that, this, where, what, unconstrained, these, vestige, disconnection,
# Nearest to they: we, you, he, there, gonadal, she, tenured, inclined,
# Nearest to with: bore, megaptera, vei, between, xiith, lyotropic, describing, inquisitional,
# Nearest to the: attempting, its, their, mes, gissing, novellae, concilium, swindle,
# Nearest to but: however, although, though, see, and, while, because, biopsy,
# Nearest to some: many, several, various, numerous, certain, most, all, hundreds,
# Nearest to three: four, five, six, seven, two, eight, zero, ten,
# Nearest to eight: six, seven, five, nine, four, three, zero, chapter,
# Nearest to an: another, assayed, rito, collectivists, spiner, stelios, parapsychologists, hives,
# Nearest to s: his, whose, dube, rbb, kth, lope, interconverts, freescale,
# Nearest to at: near, during, unassisted, stallings, webtv, dismas, around, marillion,
# Nearest to other: various, professionals, speckled, individual, fewer, these, accumulated, axial,
# Nearest to also: below, now, disambiguation, still, already, actually, cupbearer, peloponessus,
# Nearest to its: their, his, our, her, ieng, whose, regno, the,
# Nearest to are: were, is, remain, exist, include, contain, ccny, beag,
# Average loss at step 242000: 2.087502
# Average loss at step 244000: 2.110795
# Average loss at step 246000: 2.022897
# Average loss at step 248000: 2.086306
# Average loss at step 250000: 2.070422
# Nearest to had: has, have, having, was, paralysed, priestley, ve, mieczys,
# Nearest to which: that, this, where, what, unconstrained, disconnection, these, wortley,
# Nearest to they: we, you, he, there, gonadal, centralising, onna, she,
# Nearest to with: bore, vei, megaptera, between, xiith, plus, describing, lyotropic,
# Nearest to the: its, mes, attempting, a, cateau, their, banarsidass, our,
# Nearest to but: however, although, though, see, while, trap, because, and,
# Nearest to some: many, several, various, certain, numerous, most, all, both,
# Nearest to three: four, five, six, seven, two, eight, ten, zero,
# Nearest to eight: six, seven, nine, five, four, three, zero, bit,
# Nearest to an: another, collectivists, rito, assayed, spiner, stelios, parapsychologists, deter,
# Nearest to s: whose, his, rbb, kth, dube, lope, freescale, drachmas,
# Nearest to at: near, during, stallings, around, unassisted, dismas, marillion, webtv,
# Nearest to other: professionals, various, speckled, individual, fewer, these, accumulated, csm,
# Nearest to also: below, disambiguation, now, still, cupbearer, often, peloponessus, fulmar,
# Nearest to its: their, his, our, her, the, whose, ieng, regno,
# Nearest to are: were, is, remain, exist, contain, include, beag, have,
# Average loss at step 252000: 1.874675
# Average loss at step 254000: 1.791522
# Average loss at step 256000: 1.973832
# Average loss at step 258000: 2.013168
# Average loss at step 260000: 2.031383
# Nearest to had: has, have, having, ve, showed, paralysed, was, priestley,
# Nearest to which: that, this, where, what, unconstrained, disconnection, contrabass, ubisoft,
# Nearest to they: we, you, he, she, there, gonadal, onna, honed,
# Nearest to with: xiith, vei, bore, megaptera, between, plus, psychohistory, regulatory,
# Nearest to the: mes, its, attempting, gissing, concilium, cateau, coriander, our,
# Nearest to but: however, although, though, because, trap, while, macivory, see,
# Nearest to some: many, several, numerous, various, certain, most, all, both,
# Nearest to three: four, five, six, seven, two, eight, ten, zero,
# Nearest to eight: six, seven, nine, five, four, three, zero, hashed,
# Nearest to an: another, rito, assayed, collectivists, spiner, stelios, parapsychologists, deter,
# Nearest to s: his, whose, kth, rbb, drachmas, my, isbn, lope,
# Nearest to at: near, during, unassisted, stallings, webtv, bibles, nielsen, marillion,
# Nearest to other: various, professionals, speckled, fewer, individual, these, accumulated, csm,
# Nearest to also: below, disambiguation, now, still, often, already, nevertheless, cupbearer,
# Nearest to its: their, his, her, our, ieng, whose, the, regno,
# Nearest to are: were, is, remain, exist, contain, include, beag, ccny,
# Average loss at step 262000: 2.060040
# Average loss at step 264000: 1.925481
# Average loss at step 266000: 2.029007
# Average loss at step 268000: 2.044091
# Average loss at step 270000: 2.068924
# Nearest to had: has, have, having, ve, showed, paralysed, priestley, was,
# Nearest to which: where, this, that, what, disconnection, sequential, unconstrained, omb,
# Nearest to they: we, you, he, she, there, gonadal, honed, onna,
# Nearest to with: bore, vei, xiith, megaptera, between, plus, wikitravel, clipper,
# Nearest to the: mes, attempting, its, our, eurasianet, a, bumping, wajda,
# Nearest to but: however, although, though, see, trap, because, macivory, while,
# Nearest to some: many, several, numerous, various, certain, most, hundreds, all,
# Nearest to three: four, five, six, seven, two, eight, ten, paullinus,
# Nearest to eight: seven, six, four, nine, five, zero, three, vitriolic,
# Nearest to an: another, rito, assayed, collectivists, stelios, spiner, parapsychologists, considerable,
# Nearest to s: whose, rbb, dube, kth, his, my, isbn, yam,
# Nearest to at: near, during, webtv, unassisted, bibles, stallings, marillion, around,
# Nearest to other: various, speckled, fewer, individual, professionals, accumulated, fiefdoms, these,
# Nearest to also: below, disambiguation, now, still, already, often, cupbearer, actually,
# Nearest to its: their, his, our, her, whose, ieng, regno, your,
# Nearest to are: were, is, remain, exist, contain, include, have, represent,
# Average loss at step 272000: 1.945107
# Average loss at step 274000: 1.869127
# Average loss at step 276000: 1.932184
# Average loss at step 278000: 2.020558
# Average loss at step 280000: 1.984627
# Nearest to had: has, have, having, showed, ve, paralysed, priestley, was,
# Nearest to which: that, where, this, what, unconstrained, these, disconnection, gham,
# Nearest to they: we, you, he, she, there, gonadal, honed, corticospinal,
# Nearest to with: bore, megaptera, vei, plus, xiith, between, regulatory, describing,
# Nearest to the: its, attempting, banarsidass, mes, bumping, swindle, eurasianet, their,
# Nearest to but: however, although, though, see, because, trap, while, and,
# Nearest to some: many, several, numerous, various, certain, most, both, wainwright,
# Nearest to three: four, five, seven, two, six, eight, ten, fifty,
# Nearest to eight: seven, six, four, five, nine, zero, three, bit,
# Nearest to an: another, assayed, collectivists, rito, spiner, parapsychologists, stelios, fumarate,
# Nearest to s: rbb, kth, whose, carat, isbn, freescale, lindow, lope,
# Nearest to at: near, during, webtv, unassisted, bibles, around, stallings, viking,
# Nearest to other: various, speckled, professionals, individual, fewer, these, accumulated, fiefdoms,
# Nearest to also: disambiguation, now, still, below, already, cupbearer, actually, currently,
# Nearest to its: their, his, our, her, your, whose, ieng, regno,
# Nearest to are: were, is, remain, contain, exist, include, represent, beag,
# Average loss at step 282000: 2.020241
# Average loss at step 284000: 2.056271
# Average loss at step 286000: 2.000629
# Average loss at step 288000: 1.985553
# Average loss at step 290000: 2.019178
# Nearest to had: has, have, having, ve, showed, priestley, was, paralysed,
# Nearest to which: that, where, this, what, whom, unconstrained, disconnection, these,
# Nearest to they: we, you, he, she, there, tenured, honed, gonadal,
# Nearest to with: bore, xiith, vei, megaptera, between, describing, sanaga, plus,
# Nearest to the: its, mes, gissing, our, dolmens, swindle, zenga, attempting,
# Nearest to but: however, although, though, see, and, because, levied, trap,
# Nearest to some: many, several, various, numerous, certain, most, all, both,
# Nearest to three: four, five, seven, six, two, eight, zero, ten,
# Nearest to eight: six, seven, five, nine, four, three, zero, two,
# Nearest to an: another, collectivists, rito, assayed, stelios, spiner, readmission, bouillon,
# Nearest to s: rbb, kth, whose, freescale, durrani, my, lope, candlemakers,
# Nearest to at: near, during, webtv, unassisted, stallings, around, nielsen, kei,
# Nearest to other: various, individual, speckled, these, fewer, professionals, accumulated, geraldine,
# Nearest to also: disambiguation, now, still, below, already, cupbearer, actually, nevertheless,
# Nearest to its: their, our, his, her, your, whose, ieng, the,
# Nearest to are: were, is, remain, contain, exist, include, represent, beag,
# Average loss at step 292000: 1.934628
# Average loss at step 294000: 2.000271
# Average loss at step 296000: 1.997804
# Average loss at step 298000: 2.033293
# Average loss at step 300000: 2.031745
# Nearest to had: has, have, having, ve, was, were, paralysed, showed,
# Nearest to which: that, where, this, what, these, unconstrained, iniquities, vestige,
# Nearest to they: we, you, he, she, there, gonadal, corticospinal, onna,
# Nearest to with: bore, megaptera, xiith, vei, clipper, plus, villon, celeron,
# Nearest to the: its, attempting, swindle, cateau, our, umb, their, concilium,
# Nearest to but: however, although, though, see, and, trap, idiosyncrasy, because,
# Nearest to some: many, several, various, numerous, certain, most, all, hundreds,
# Nearest to three: four, seven, six, five, two, eight, zero, ten,
# Nearest to eight: six, seven, five, four, nine, three, zero, two,
# Nearest to an: another, rito, collectivists, assayed, spiner, stelios, parapsychologists, bouillon,
# Nearest to s: rbb, kth, whose, freescale, hove, lope, dube, durrani,
# Nearest to at: near, during, webtv, unassisted, stallings, around, murmansk, bibles,
# Nearest to other: various, speckled, individual, these, fewer, professionals, accumulated, geraldine,
# Nearest to also: now, disambiguation, below, still, already, cupbearer, actually, nevertheless,
# Nearest to its: their, his, our, her, whose, your, ieng, the,
# Nearest to are: were, is, remain, contain, exist, include, beag, represent,
# Average loss at step 302000: 1.961514
# Average loss at step 304000: 1.991750
# Average loss at step 306000: 2.031666
# Average loss at step 308000: 2.047030
# Average loss at step 310000: 2.034909
# Nearest to had: has, have, having, ve, was, showed, were, paralysed,
# Nearest to which: that, this, where, what, vestige, these, whom, unconstrained,
# Nearest to they: we, you, he, there, she, gonadal, honed, onna,
# Nearest to with: bore, vei, xiith, megaptera, between, plus, celeron, lyotropic,
# Nearest to the: bumping, a, swindle, mes, its, zenga, their, attempting,
# Nearest to but: however, although, though, and, see, trap, macivory, idiosyncrasy,
# Nearest to some: many, several, various, numerous, certain, most, hundreds, both,
# Nearest to three: four, two, five, six, seven, eight, ten, zero,
# Nearest to eight: six, seven, five, four, nine, zero, three, vitriolic,
# Nearest to an: another, collectivists, assayed, rito, spiner, parapsychologists, stelios, considerable,
# Nearest to s: whose, his, kth, rbb, hove, helmuth, dube, freescale,
# Nearest to at: near, webtv, unassisted, during, bibles, murmansk, stallings, worth,
# Nearest to other: various, individual, speckled, fewer, these, professionals, accumulated, fiefdoms,
# Nearest to also: disambiguation, still, now, below, actually, cupbearer, clarisworks, already,
# Nearest to its: their, his, our, her, whose, your, ieng, regno,
# Nearest to are: were, is, remain, contain, include, exist, represent, beag,
# Average loss at step 312000: 2.042715
# Average loss at step 314000: 1.965493
# Average loss at step 316000: 1.864697
# Average loss at step 318000: 2.006965
# Average loss at step 320000: 1.986099
# Nearest to had: has, have, having, ve, was, showed, were, paralysed,
# Nearest to which: that, what, where, this, unconstrained, these, whom, disconnection,
# Nearest to they: we, you, he, there, gonadal, she, tenured, honed,
# Nearest to with: bore, vei, xiith, between, megaptera, plus, qaghans, nanotechnologies,
# Nearest to the: mes, a, its, cateau, zenga, our, attempting, eurasianet,
# Nearest to but: however, although, though, see, trap, macivory, biopsy, compaor,
# Nearest to some: many, several, various, numerous, certain, most, wainwright, all,
# Nearest to three: four, five, six, two, seven, eight, ten, several,
# Nearest to eight: six, seven, nine, five, four, zero, three, two,
# Nearest to an: collectivists, another, assayed, rito, stelios, spiner, parapsychologists, fumarate,
# Nearest to s: kth, whose, rbb, morita, dube, freescale, his, lope,
# Nearest to at: near, webtv, unassisted, during, marillion, viking, murmansk, stallings,
# Nearest to other: various, speckled, fewer, individual, these, professionals, accumulated, moirae,
# Nearest to also: disambiguation, still, below, now, actually, nevertheless, already, cupbearer,
# Nearest to its: their, his, our, whose, her, ieng, your, regno,
# Nearest to are: were, is, remain, contain, exist, include, represent, beag,
# Average loss at step 322000: 1.986569
# Average loss at step 324000: 2.019417
# Average loss at step 326000: 2.054904
# Average loss at step 328000: 2.019811
# Average loss at step 330000: 2.036924
# Nearest to had: has, have, having, ve, was, were, priestley, paralysed,
# Nearest to which: this, that, what, where, these, unconstrained, whom, disconnection,
# Nearest to they: we, you, he, she, gonadal, there, tenured, honed,
# Nearest to with: bore, vei, xiith, megaptera, poissy, between, qaghans, plus,
# Nearest to the: its, attempting, their, mes, a, umb, xnor, zenga,
# Nearest to but: however, although, though, see, and, while, macivory, trap,
# Nearest to some: many, several, numerous, various, certain, most, all, hundreds,
# Nearest to three: four, five, six, two, seven, eight, mb, zero,
# Nearest to eight: six, seven, nine, five, four, zero, three, bureaucrash,
# Nearest to an: another, collectivists, rito, assayed, stelios, parapsychologists, spiner, compuware,
# Nearest to s: kth, whose, rbb, his, delamielleure, dube, murray, bolshoi,
# Nearest to at: near, during, unassisted, webtv, viking, stallings, around, boatswain,
# ...
# Average loss at step 396000: 1.945572
# Average loss at step 398000: 1.974120
# Average loss at step 400000: 1.854021
# Nearest to had: has, have, having, ve, paralysed, was, showed, mieczys,
# Nearest to which: this, where, what, that, whom, disconnection, omb, ubisoft,
# Nearest to they: we, you, he, she, there, gonadal, onna, honed,
# Nearest to with: vei, bore, xiith, megaptera, plus, between, intendant, clipper,
# Nearest to the: mes, its, attempting, cateau, banarsidass, egas, a, their,
# Nearest to but: however, although, though, see, and, macivory, trap, while,
# Nearest to some: many, several, various, numerous, most, certain, hundreds, all,
# Nearest to three: four, five, six, seven, two, eight, zero, ten,
# Nearest to eight: six, seven, four, nine, five, zero, three, bit,
# Nearest to an: another, rito, assayed, collectivists, stelios, spiner, parapsychologists, fumarate,
# Nearest to s: rbb, whose, freescale, kth, yasukuni, sectarianism, sycophantic, lope,
# Nearest to at: near, during, webtv, unassisted, viking, around, marillion, aficionados,
# Nearest to other: various, fewer, speckled, these, individual, professionals, fiefdoms, accumulated,
# Nearest to also: disambiguation, now, still, already, below, actually, currently, nevertheless,
# Nearest to its: their, his, our, her, whose, ieng, your, regno,
# Nearest to are: were, is, exist, contain, remain, include, have, beag,
# Average loss at step 402000: 1.787729
# Average loss at step 404000: 1.862546
# Average loss at step 406000: 1.934772
# Average loss at step 408000: 1.896519
# Average loss at step 410000: 1.945119
# Nearest to had: has, have, having, ve, was, were, priestley, paralysed,
# Nearest to which: where, that, what, this, unconstrained, whom, disconnection, these,
# Nearest to they: we, you, he, she, there, gonadal, honed, corticospinal,
# Nearest to with: bore, vei, megaptera, xiith, lyotropic, plus, between, kripke,
# Nearest to the: attempting, their, a, its, mes, swindle, banarsidass, hyperreflexia,
# Nearest to but: however, although, though, see, biopsy, while, because, and,
# Nearest to some: many, several, numerous, various, certain, most, both, hundreds,
# Nearest to three: four, five, seven, two, six, eight, zero, ten,
# Nearest to eight: six, seven, four, five, three, zero, nine, iconoclastic,
# Nearest to an: another, rito, collectivists, assayed, spiner, stelios, fumarate, parapsychologists,
# Nearest to s: rbb, whose, freescale, his, kth, lope, lindow, carat,
# Nearest to at: near, during, unassisted, webtv, viking, stallings, around, generates,
# Nearest to other: various, these, speckled, fewer, individual, professionals, doctrinal, different,
# Nearest to also: disambiguation, now, still, already, actually, below, nevertheless, cupbearer,
# Nearest to its: their, his, our, her, whose, your, ieng, my,
# Nearest to are: were, is, exist, contain, remain, represent, include, differ,
# Average loss at step 412000: 1.966897
# Average loss at step 414000: 1.924549
# Average loss at step 416000: 1.890016
# Average loss at step 418000: 1.930372
# Average loss at step 420000: 1.855851
# Nearest to had: has, have, having, ve, was, priestley, paralysed, were,
# Nearest to which: where, that, this, what, whom, unconstrained, these, disconnection,
# Nearest to they: we, you, he, she, there, gonadal, honed, minn,
# Nearest to with: bore, xiith, megaptera, between, vei, lyotropic, kippur, compacta,
# Nearest to the: its, their, mes, gissing, hyperreflexia, banarsidass, zenga, cateau,
# Nearest to but: however, although, though, see, and, because, biopsy, levied,
# Nearest to some: many, several, various, numerous, certain, most, hundreds, both,
# Nearest to three: four, five, seven, six, two, eight, zero, ten,
# Nearest to eight: six, seven, five, four, nine, three, zero, two,
# Nearest to an: another, collectivists, rito, assayed, stelios, spiner, parapsychologists, fumarate,
# Nearest to s: whose, rbb, freescale, kth, his, lope, dube, pickering,
# Nearest to at: near, during, unassisted, webtv, stallings, viking, kei, aficionados,
# Nearest to other: various, these, speckled, fewer, individual, doctrinal, accumulated, professionals,
# Nearest to also: disambiguation, now, still, actually, already, nevertheless, below, cupbearer,
# Nearest to its: their, his, our, whose, her, your, ieng, my,
# Nearest to are: were, is, contain, remain, exist, include, represent, beag,
# Average loss at step 422000: 1.925286
# Average loss at step 424000: 1.923474
# Average loss at step 426000: 1.949559
# Average loss at step 428000: 1.949153
# Average loss at step 430000: 1.850831
# Nearest to had: has, have, having, ve, was, were, paralysed, priestley,
# Nearest to which: that, where, this, what, whom, unconstrained, disconnection, vestige,
# Nearest to they: we, you, he, she, there, gonadal, honed, onna,
# Nearest to with: bore, megaptera, vei, xiith, between, whilst, clipper, lyotropic,
# Nearest to the: its, swindle, mes, coriander, gissing, freikorps, banarsidass, umb,
# Nearest to but: however, although, though, see, and, because, macivory, digested,
# Nearest to some: many, several, numerous, various, certain, most, hundreds, both,
# Nearest to three: four, seven, five, six, two, eight, ten, zero,
# Nearest to eight: six, seven, four, five, nine, three, zero, intelsat,
# Nearest to an: another, collectivists, rito, spiner, parapsychologists, stelios, assayed, fumarate,
# Nearest to s: whose, rbb, kth, lope, pickering, pregroove, freescale, candlemakers,
# Nearest to at: near, during, viking, webtv, unassisted, stallings, bibles, around,
# Nearest to other: various, these, speckled, fewer, individual, professionals, accumulated, thermoelectricity,
# Nearest to also: disambiguation, now, already, actually, still, below, nevertheless, currently,
# Nearest to its: their, his, our, whose, her, your, the, ieng,
# Nearest to are: were, is, remain, exist, contain, represent, beag, include,
# Average loss at step 432000: 1.937531
# Average loss at step 434000: 1.959443
# Average loss at step 436000: 1.977712
# Average loss at step 438000: 1.937342
# Average loss at step 440000: 1.963070
# Nearest to had: has, have, having, ve, were, chooses, priestley, was,
# Nearest to which: this, where, that, what, whom, unconstrained, vestige, these,
# Nearest to they: we, you, he, she, there, gonadal, honed, onna,
# Nearest to with: bore, vei, xiith, megaptera, plus, between, clipper, whilst,
# Nearest to the: swindle, its, zenga, banarsidass, hina, kebabs, a, mes,
# Nearest to but: however, although, though, and, see, while, biopsy, trap,
# Nearest to some: many, several, numerous, various, certain, most, hundreds, both,
# Nearest to three: four, five, two, six, seven, eight, ten, twelve,
# Nearest to eight: six, seven, five, nine, four, zero, three, vitriolic,
# Nearest to an: another, collectivists, assayed, rito, parapsychologists, spiner, stelios, fumarate,
# Nearest to s: whose, his, rbb, hove, kth, freescale, bongo, dube,
# Nearest to at: near, unassisted, webtv, during, viking, stallings, aficionados, marillion,
# Nearest to other: various, fewer, speckled, these, individual, professionals, thermoelectricity, doctrinal,
# Nearest to also: disambiguation, actually, still, now, below, already, nevertheless, currently,
# Nearest to its: their, his, our, her, whose, your, ieng, regno,
# Nearest to are: were, is, remain, contain, exist, represent, include, have,
# Average loss at step 442000: 1.890662
# Average loss at step 444000: 1.790076
# Average loss at step 446000: 1.923713
# Average loss at step 448000: 1.910428
# Average loss at step 450000: 1.891275
# Nearest to had: has, have, having, ve, were, priestley, paralysed, mieczys,
# Nearest to which: where, that, this, what, unconstrained, these, whom, disconnection,
# Nearest to they: we, you, he, she, gonadal, there, honed, centralising,
# Nearest to with: bore, vei, megaptera, xiith, between, plus, qaghans, lyotropic,
# Nearest to the: its, banarsidass, a, umb, zenga, swindle, kachin, charing,
# Nearest to but: however, although, though, see, while, and, macivory, biopsy,
# Nearest to some: many, several, various, numerous, certain, most, few, all,
# Nearest to three: four, five, six, two, seven, eight, ten, lev,
# Nearest to eight: six, seven, nine, five, four, zero, three, xb,
# Nearest to an: another, collectivists, rito, assayed, stelios, parapsychologists, spiner, fumarate,
# Nearest to s: rbb, whose, kth, dube, returns, his, delamielleure, mechatronics,
# Nearest to at: near, webtv, viking, during, unassisted, stallings, worth, marillion,
# Nearest to other: various, these, speckled, fewer, individual, doctrinal, including, thermoelectricity,
# Nearest to also: disambiguation, now, still, actually, below, nevertheless, already, here,
# Nearest to its: their, his, our, her, whose, ieng, your, my,
# Nearest to are: were, is, contain, remain, represent, exist, include, differ,
# Average loss at step 452000: 1.954374
# Average loss at step 454000: 1.966815
# Average loss at step 456000: 1.949381
# Average loss at step 458000: 1.947095
# Average loss at step 460000: 1.900445
# Nearest to had: has, have, having, ve, were, was, priestley, paralysed,
# Nearest to which: this, that, what, where, unconstrained, these, whom, disconnection,
# Nearest to they: we, you, he, gonadal, she, there, honed, belies,
# Nearest to with: bore, vei, megaptera, xiith, plus, clipper, poissy, qaghans,
# Nearest to the: its, mes, a, bumping, zcoa, eurasianet, umb, novellae,
# Nearest to but: however, although, though, see, and, fooling, while, which,
# Nearest to some: many, several, numerous, various, certain, most, few, all,
# Nearest to three: four, five, six, seven, two, eight, twelve, ten,
# Nearest to eight: six, seven, five, nine, four, three, zero, bureaucrash,
# Nearest to an: another, rito, collectivists, assayed, stelios, parapsychologists, spiner, fumarate,
# Nearest to s: kth, whose, rbb, dube, delamielleure, his, returns, freescale,
# Nearest to at: near, webtv, viking, stallings, unassisted, during, marillion, ransome,
# Nearest to other: various, speckled, fewer, individual, these, doctrinal, geraldine, thermoelectricity,
# Nearest to also: disambiguation, now, actually, below, still, nevertheless, already, cupbearer,
# Nearest to its: their, his, our, her, whose, your, ieng, my,
# Nearest to are: were, is, contain, remain, exist, represent, include, differ,
# Average loss at step 462000: 1.899099
# Average loss at step 464000: 1.922763
# Average loss at step 466000: 1.945796
# Average loss at step 468000: 1.851006
# Average loss at step 470000: 1.917548
# Nearest to had: has, have, having, were, ve, was, paralysed, mieczys,
# Nearest to which: that, where, this, what, these, unconstrained, whom, disconnection,
# Nearest to they: we, you, he, gonadal, there, she, honed, centralising,
# Nearest to with: vei, bore, xiith, megaptera, louse, plus, poissy, clipper,
# Nearest to the: mes, zenga, a, cateau, concilium, eurasianet, swindle, bumping,
# Nearest to but: however, although, though, see, and, because, fooling, while,
# Nearest to some: many, several, numerous, various, certain, few, most, hundreds,
# Nearest to three: four, five, six, seven, two, eight, zero, twelve,
# Nearest to eight: seven, six, nine, five, four, three, zero, obnoxious,
# Nearest to an: another, collectivists, assayed, rito, parapsychologists, fumarate, stelios, spiner,
# Nearest to s: whose, kth, rbb, returns, dube, his, freescale, delamielleure,
# Nearest to at: near, unassisted, during, webtv, stallings, viking, kei, around,
# Nearest to other: various, fewer, speckled, individual, these, doctrinal, csm, others,
# Nearest to also: disambiguation, now, actually, below, still, nevertheless, already, cupbearer,
# Nearest to its: their, our, his, her, your, whose, ieng, my,
# Nearest to are: were, is, remain, exist, contain, represent, differ, have,
# Average loss at step 472000: 1.928022
# Average loss at step 474000: 1.914374
# Average loss at step 476000: 1.887509
# Average loss at step 478000: 1.848510
# Average loss at step 480000: 1.897610
# Nearest to had: has, have, having, ve, were, was, mieczys, paralysed,
# Nearest to which: that, this, where, what, unconstrained, these, whom, disconnection,
# Nearest to they: we, you, he, gonadal, there, she, honed, tenured,
# Nearest to with: bore, vei, megaptera, xiith, plus, between, poissy, lyotropic,
# Nearest to the: a, mes, its, cateau, bumping, attempting, buwei, their,
# Nearest to but: however, although, though, see, because, and, biopsy, while,
# Nearest to some: many, several, numerous, various, certain, few, most, hundreds,
# Nearest to three: four, five, six, seven, two, eight, twelve, fifty,
# Nearest to eight: six, seven, five, four, nine, zero, three, pdp,
# Nearest to an: another, assayed, collectivists, rito, spiner, parapsychologists, fumarate, klietz,
# Nearest to s: kth, whose, dube, his, rbb, returns, kryuchkov, freescale,
# Nearest to at: near, during, unassisted, webtv, viking, around, stallings, kei,
# Nearest to other: various, speckled, fewer, individual, these, doctrinal, csm, professionals,
# Nearest to also: disambiguation, now, actually, already, nevertheless, still, below, cupbearer,
# Nearest to its: their, his, our, her, whose, your, ieng, regno,
# Nearest to are: were, is, contain, remain, exist, represent, include, differ,
# Average loss at step 482000: 1.952787
# Average loss at step 484000: 1.804555
# Average loss at step 486000: 1.923455
# Average loss at step 488000: 1.937018
# Average loss at step 490000: 1.940170
# Nearest to had: has, have, having, ve, were, mieczys, paralysed, showed,
# Nearest to which: that, this, what, where, unconstrained, whom, these, disconnection,
# Nearest to they: we, you, he, there, she, gonadal, centralising, tenured,
# Nearest to with: bore, vei, xiith, megaptera, plus, johansen, between, poissy,
# Nearest to the: gissing, a, cateau, thy, its, zenga, swindle, our,
# Nearest to but: however, although, though, see, and, because, biopsy, macivory,
# Nearest to some: many, several, numerous, various, certain, most, few, both,
# Nearest to three: four, five, six, seven, two, eight, fifty, zero,
# Nearest to eight: six, seven, five, nine, four, zero, three, pdp,
# Nearest to an: another, collectivists, assayed, rito, parapsychologists, spiner, klietz, hives,
# Nearest to s: whose, kth, his, rbb, dube, freescale, returns, lope,
# Nearest to at: near, during, unassisted, viking, stallings, webtv, dismas, around,
# Nearest to other: various, fewer, speckled, individual, these, others, professionals, doctrinal,
# Nearest to also: disambiguation, now, actually, nevertheless, below, already, still, cupbearer,
# Nearest to its: their, his, our, her, your, whose, ieng, my,
# Nearest to are: were, is, contain, exist, remain, include, represent, differ,
# Average loss at step 492000: 1.843066
# Average loss at step 494000: 1.921547
# Average loss at step 496000: 1.891841
# Average loss at step 498000: 1.916304
# Average loss at step 500000: 1.911669
# Nearest to had: has, have, having, ve, was, were, paralysed, priestley,
# Nearest to which: this, where, that, what, unconstrained, whom, these, disconnection,
# Nearest to they: we, you, he, there, she, gonadal, honed, centralising,
# Nearest to with: bore, vei, megaptera, plus, between, xiith, lyotropic, amongst,
# Nearest to the: its, mes, a, their, umb, eurasianet, zenga, hyperreflexia,
# Nearest to but: however, although, though, see, biopsy, because, and, furthermore,
# Nearest to some: many, several, numerous, certain, various, most, few, all,
# Nearest to three: four, five, six, seven, two, eight, fifty, twelve,
# Nearest to eight: seven, six, five, nine, four, zero, three, intelsat,
# Nearest to an: another, collectivists, assayed, spiner, rito, parapsychologists, stelios, fumarate,
# Nearest to s: whose, returns, rbb, dube, kth, his, kryuchkov, freescale,
# Nearest to at: near, during, viking, unassisted, stallings, around, dismas, marillion,
# Nearest to other: various, fewer, these, speckled, individual, including, others, axial,
# Nearest to also: disambiguation, now, nevertheless, actually, still, already, below, currently,
# Nearest to its: their, his, our, her, whose, your, ieng, the,
# Nearest to are: were, is, exist, contain, remain, include, represent, have,
